# %% [markdown]
# # 00 — Environment Check
#
# Verifies the analysis environment and the canonical data location.

# %%
import sys, platform
import pandas, numpy, matplotlib
print("python", sys.version.split()[0], platform.system())
for m in (pandas, numpy, matplotlib):
    print(m.__name__, m.__version__)

# %%
from notion_zotero.analysis import la_review_figure_data as fd
CANONICAL_DIR = fd._REPO_ROOT / "data" / "pulled" / "notion" / "learning_analytics_review"
n = len(list(CANONICAL_DIR.glob("*.canonical.json")))
assert CANONICAL_DIR.exists() and n > 0, "canonical bundles not found"
print("canonical bundles:", n)

# %% [markdown]
# Environment OK — proceed to `01_data_audit.ipynb`.
